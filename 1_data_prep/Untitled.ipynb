# %%
import pandas as pd

# %%
df = pd.read_csv("./wealth_indices_2019_USA.csv")
df.head()
# Out:
#                                             NAME  median_home_value  \
# 0     Census Tract 11, Jefferson County, Alabama            85500.0
# 1     Census Tract 14, Jefferson County, Alabama            67800.0
# 2     Census Tract 20, Jefferson County, Alabama            68400.0
# 3  Census Tract 38.02, Jefferson County, Alabama            64100.0
# 4     Census Tract 40, Jefferson County, Alabama            67300.0
#
#    median_year_built  median_gross_rent  median_rooms  total_housing_units  \
# 0             1978.0              621.0           5.9                 1851
# 1             1953.0              738.0           5.4                  816
# 2             1957.0              692.0           5.2                 1419
# 3             1955.0              876.0           5.5                 1894
# 4             1965.0              594.0           4.4                 1429
#
#    owner_occupied_units  total_units_in_structure  units_1_detached  \
# ...

# %%
print([i for i in df.columns])
# Out:
# ['NAME', 'median_home_value', 'median_year_built', 'median_gross_rent', 'median_rooms', 'total_housing_units', 'owner_occupied_units', 'total_units_in_structure', 'units_1_detached', 'units_1_attached', 'total_bedrooms', 'crowding_total_households', 'owner_crowded_1_01_to_1_50_occupants', 'owner_severely_crowded_1_51_plus_occupants', 'renter_crowded_1_01_to_1_50_occupants', 'renter_severely_crowded_1_51_plus_occupants', 'vehicles_total_households', 'owner_1_vehicle', 'owner_2_vehicles', 'owner_3_plus_vehicles', 'renter_1_vehicle', 'renter_2_vehicles', 'renter_3_plus_vehicles', 'internet_total_households', 'broadband_internet', 'computer_total_households', 'has_computer', 'heating_total_households', 'utility_gas_heat', 'electricity_heat', 'fuel_oil_kerosene_heat', 'wood_heat', 'median_household_income', 'per_capita_income', 'poverty_total_population', 'population_below_poverty_line', 'labor_force_total', 'unemployed', 'rent_burden_universe', 'rent_burdened_30_34', 'rent_burdened_35_39
# ...
