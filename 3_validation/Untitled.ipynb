# %%
from sklearn.metrics import r2_score
import pandas as pd

# %%
df = pd.read_csv("/data/hbaier/new_data/tlag/az_imagery/q1_2016_s2_allbands/artifacts/az_q1_2016_allbands_v2/epoch185_valset_preds.csv")
df.head()
# Out:
#    Unnamed: 0                                               name      pred  \
# 0           0  /data/hbaier/new_data/tlag/az_imagery/q1_2016_... -0.094926
# 1           1  /data/hbaier/new_data/tlag/az_imagery/q1_2016_... -0.622567
# 2           2  /data/hbaier/new_data/tlag/az_imagery/q1_2016_... -1.736081
# 3           3  /data/hbaier/new_data/tlag/az_imagery/q1_2016_...  0.244933
# 4           4  /data/hbaier/new_data/tlag/az_imagery/q1_2016_... -0.064087
#
#       label  extra
# 0  0.308092      0
# 1 -0.192603      0
# 2 -1.367819      0
# 3  0.641523      0
# 4 -0.027274      0

# %%
r2_score(df["label"], df["pred"])
# Out:
# 0.10691958312416294
