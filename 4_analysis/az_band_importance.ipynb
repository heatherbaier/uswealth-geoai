# %%
import pandas as pd

# %%
df = pd.read_csv("/data/hbaier/new_data/tlag/az_imagery/q1_2016_s2_allbands/artifacts/az_q1_2016_allbands_v1/band_importance.csv")
df.sort_values(by = "band_index")
# Out:
#     band_index band_name  baseline_mse  delta_mse  delta_mse_std  pct_increase
# 11           0       B01      0.636966   0.012788       0.031448      2.007665
# 0            1       B02      0.636966   0.230359       0.022020     36.165074
# 1            2       B03      0.636966   0.172822       0.023831     27.132067
# 6            3       B04      0.636966   0.050026       0.032830      7.853853
# 5            4       B05      0.636966   0.058495       0.015253      9.183326
# 8            5       B06      0.636966   0.034171       0.006234      5.364645
# 4            6       B07      0.636966   0.074313       0.014580     11.666680
# 10           7       B08      0.636966   0.022417       0.021787      3.519296
# 7            8       B8A      0.636966   0.038881       0.030469      6.104096
# 9            9       B09      0.636966   0.026698       0.016546      4.191440
# 3           10       B11      0.636966   0.106495       0.043372     16.719161
# ...
